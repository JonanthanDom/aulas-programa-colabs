# %% [markdown]
# <a href="https://colab.research.google.com/github/JonanthanDom/aulas-programa-colabs/blob/main/analisadorLexico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#analisador lexico para linguagem python
#dicionarios
Python = {'palavrasChave':['and','print',	'as',	'assert',	'break','class',	'continue',	'def',	'del', 'elif',	'else',	'except',	'False', 'finally',	'for','from',	'global', 'if',	'import',	'in',	'is', 'lambda',	'None',	'nonlocal',	'not', 'or', 	'pass',	'raise',	'return','True',	'try', 'while',	'with','yield'], 'Operadores' :['+', '-', '*', '/', '%', '**', '//', '=', '+=', '-=', '*=', '/=', '%=', '//=', '**=', '&=', '|=', "^=", '>>=', '<<=', '==', '!=', '<','>', '<=' '>=', 'and', 'or,' 'not', 'is', 'is not', 'in', 'not in', '&', "|", '^', '~', '<<', ">>", '+x', '-x', '~x'], "Delimitadores" : ['(', ')', '[', ']', '{', '}', ':' ]}
Java = {'palavrasChave' :['abstract', 'assert', 'boolean', 'break', 'byte', 'case', 'catch', 'char', 'class', 'continue', 'const', 'default', 'do', 'double', 'else', 'enun', 'exports', 'extends', 'final', 'finaly', 'float', 'for', 'goto', 'if', 'implements', 'import', 'instanceof', 'int', 'interface', 'long', 'module', 'native', 'new', 'packcage', 'private', 'protected', 'public', 'requires', 'return', 'short', 'static', 'strictfp', 'super', 'switch', 'syncronyzed', 'this', 'throw', 'throws', 'transient', 'try', 'var', 'void', 'volatile', 'while', 'true', 'false', 'null'], 'Operadores' : ['+', '-', '*', '/', '%', '++', '--', '=', '+=', '-=', '*=', '/=', '%=', '&=', '|=', '^=', '>>=', '<<=', '==', '!=', '>', '<', '>=', '<=', '&&', '||', '!'], "Delimitadores" : ['(', ')', '[', ']', '{', '}', ':', ';' ]}
PHP = {'palavrasChave' :['abstract', 'and', 'as', 'break', 'callable', 'case', 'catch','class', 'clone', 'const', 'continue', 'declare', 'default', 'do', 'echo', 'else', 'elseif', 'empty', 'enddeclare', 'endfor', 'endforeach', 'endif', 'endswitch', 'endwhile','extends', 'final', 'finally', 'fn', 'for', 'foreach', 'function', 'global', 'goto', 'if', 'implements', 'include', 'include once', 'instanceof', 'insteadof', 'interface', 'isset', 'list', 'namespace', 'new', 'or', 'print', 'private', 'protected', 'public', 'require', 'require once', 'return', 'static', 'switch', 'throw', 'trait', 'try', 'unset', 'use', 'var', 'while', 'xor', 'yeld', 'yeld from'], 'Operadores' :['+', '-', '*', '/', '%', '**', '==', '===', '!=', '<>', '!==', '<', '>', '>=', '<=', '<=>', '++$x', '$x++', '--$x', '$x--', 'and', 'or', 'xor', '&&', '||', '!', '.', '.=', '?:', '??'], 'Delimitadores' :['<?php', '?>', '{', '}', '(', ')', '[', ']',';']}
#recebe a sentença a ser analisada

def python():
  palavrasChave = []
  operadores = []
  delimitadores = []
  sentenca = input("Insira o código Python a ser analizado: ")
  palavras = sentenca.split()
  for palavra in palavras:
      if(palavra in Python['palavrasChave'] and palavra not in palavrasChave):
        palavrasChave.append(palavra)
      if(palavra in Python['Operadores']and palavra not in operadores):
        operadores.append(palavra)
      if(palavra in Python['Delimitadores']and palavra not in delimitadores):
        delimitadores.append(palavra)
  if('if' not in palavrasChave and 'if(' in palavra):
    palavrasChave.append("if")
  if('(' not in delimitadores and '(' in palavra):
    delimitadores.append("()")
  if('[' not in delimitadores and '[' in palavra):
    delimitadores.append("[]")
  if('{' not in delimitadores and '{' in palavra):
    delimitadores.append("{}")
  if(';' not in delimitadores and ';' in palavra):
    delimitadores.append(";")
  if(':' not in delimitadores and ':' in palavra):
    delimitadores.append(":")
  if("'" not in delimitadores and "'" in palavra):
    delimitadores.append("''")
  if('"' not in delimitadores and '"' in palavra):
    delimitadores.append('""')
  print('\n', 'Palavras Chave:',palavrasChave, '\n' , '\n', 'Operadores:', operadores, '\n', '\n', 'Delimitadores:', delimitadores)

def java():
  palavrasChave = []
  operadores = []
  delimitadores = []
  sentenca = input("Insira o código Java a ser analizado: ")
  palavras = sentenca.split()
  for palavra in palavras:
      if(palavra in Java['palavrasChave'] and palavra not in palavrasChave):
        palavrasChave.append(palavra)
      if(palavra in Java['Operadores']and palavra not in operadores):
        operadores.append(palavra)
      if(palavra in Java['Delimitadores']and palavra not in delimitadores):
        delimitadores.append(palavra)
  if('if' not in palavrasChave and 'if(' in palavra):
    palavrasChave.append("if")
  if('(' not in delimitadores and '(' in palavra):
    delimitadores.append("()")
  if('[' not in delimitadores and '[' in palavra):
    delimitadores.append("[]")
  if('{' not in delimitadores and '{' in palavra):
    delimitadores.append("{}")
  if(';' not in delimitadores and ';' in palavra):
    delimitadores.append(";")
  if(':' not in delimitadores and ':' in palavra):
    delimitadores.append(":")
  if("'" not in delimitadores and "'" in palavra):
    delimitadores.append("''")
  if('"' not in delimitadores and '"' in palavra):
    delimitadores.append('""')
  print('\n', 'Palavras Chave:',palavrasChave, '\n' , '\n', 'Operadores:', operadores, '\n', '\n', 'Delimitadores:', delimitadores)

def php():
  palavrasChave = []
  operadores = []
  delimitadores = []
  sentenca = input("Insira o código PHP a ser analizado: ")
  palavras = sentenca.split()
  for palavra in palavras:
      if(palavra in PHP['palavrasChave'] and palavra not in palavrasChave):
        palavrasChave.append(palavra)
      if(palavra in PHP['Operadores']and palavra not in operadores):
        operadores.append(palavra)
      if(palavra in PHP['Delimitadores']and palavra not in delimitadores):
        delimitadores.append(palavra)
  if('if' not in palavrasChave and 'if(' in palavra):
    palavrasChave.append("if")
  if('(' not in delimitadores and '(' in palavra):
    delimitadores.append("()")
  if('[' not in delimitadores and '[' in palavra):
    delimitadores.append("[]")
  if('{' not in delimitadores and '{' in palavra):
    delimitadores.append("{}")
  if(';' not in delimitadores and ';' in palavra):
    delimitadores.append(";")
  if(':' not in delimitadores and ':' in palavra):
    delimitadores.append(":")
  if("'" not in delimitadores and "'" in palavra):
    delimitadores.append("''")
  if('"' not in delimitadores and '"' in palavra):
    delimitadores.append('""')
  print('\n', 'Palavras Chave:',palavrasChave, '\n' , '\n', 'Operadores:', operadores, '\n', '\n', 'Delimitadores:', delimitadores)



def menuprinc():
    opcao=int(input('''
    	  Escolha um programa
1 - Python
2 - Java
3 - PHP
0 - Sair
Escolha:  '''))
    if opcao == 1:
      python()
      opcao=int(input('''O que deseja fazer agora?
        1 nova análise
        2 sair'''))
      if opcao == 1:
          menuprinc()
      else:
          while True:
            mensagem = "Deseja sair do programa (s/n)? "
            resposta = input(mensagem)
            if resposta.lower() == "n":
              print("Aguardo a tua vontade...")
            elif resposta.lower() == "s":
              print("É uma pena que você queira sair, mas farei o possível para te fazer feliz!", '\n', "Programa finalizado")

    elif opcao == 2:
      java()
      opcao=int(input('''O que deseja fazer agora?
        1 nova análise
        2 sair'''))
      if opcao == 1:
          menuprinc()
      else:
          while True:
            mensagem = "Deseja sair do programa (s/n)? "
            resposta = input(mensagem)
            if resposta.lower() == "n":
              print("Aguardo a tua vontade...")
            elif resposta.lower() == "s":
              print("É uma pena que você queira sair, mas farei o possível para te fazer feliz!", '\n', "Programa finalizado")

    elif opcao == 3:
      php()
      opcao=int(input('''O que deseja fazer agora?
        1 nova análise
        2 sair'''))
      if opcao == 1:
          menuprinc()
      else:
          while True:
            mensagem = "Deseja sair do programa (s/n)? "
            resposta = input(mensagem)
            if resposta.lower() == "n":
              print("Aguardo a tua vontade...")
            elif resposta.lower() == "s":
              print("É uma pena que você queira sair, mas farei o possível para te fazer feliz!", '\n', "Programa finalizado")

    elif opcao == 0:
        mensagem = "Deseja sair do programa (s/n)? "
        resposta = input(mensagem)
        if resposta.lower() == "n":
          print("Aguardo a tua vontade...")
        elif resposta.lower() == "s":
          print("É uma pena que você queira sair, mas farei o possível para te fazer feliz!", '\n', "Programa finalizado")

    else:
        print("Este número não está nas alternativas, tente novamente :D.\n")
        menuprinc()
while True:
    try:
        opcao=int(input('''O que deseja fazer agora?
        1 nova análise
        2 sair'''))
        if opcao == 1:
          menuprinc()
        else:
          while True:
            mensagem = "Deseja sair do programa (s/n)? "
            resposta = input(mensagem)
            if resposta.lower() == "n":
              print("Aguardo a tua vontade...")
            elif resposta.lower() == "s":
              print("É uma pena que você queira sair, mas farei o possível para te fazer feliz!", '\n', "Programa finalizado")
              break
            else:
              print("Opção inválida, por favor escolha uma resposta válida.")
    except ValueError:
        print("Isso não é um número, tente novamente :D.\n")
    break
